# %%
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from sklearn.model_selection import train_test_split
import pycaret

# %%
data = pd.read_csv('etfs_dataset_modelling.csv')

# %%
data.dropna(inplace=True)

# %%
data = data.drop(['Unnamed: 0', 'Ticker', 'Date'], axis=1)
data
# Out:
#               Open       High        Low      Close    Volume  Dividends  \
# 25       23.820000  23.820000  23.768000  23.768000  210200.0        0.0
# 26       23.900999  23.952000  23.900999  23.952000     200.0        0.0
# 27       24.016001  24.070000  24.016001  24.049999   11300.0        0.0
# 28       23.972000  23.975000  23.972000  23.975000     200.0        0.0
# 29       23.913000  23.913000  23.913000  23.913000       0.0        0.0
# ...            ...        ...        ...        ...       ...        ...
# 3571480  29.120001  29.195000  29.120001  29.195000     200.0        0.0
# 3571481  29.221001  29.270000  29.180000  29.267000    2300.0        0.0
# 3571482  29.240000  29.297001  29.240000  29.297001     500.0        0.0
# 3571483  29.299999  29.340000  29.299999  29.332001     600.0        0.0
# 3571484  29.368000  29.368000  29.299999  29.327000    4300.0        0.0
#
#          Stock Splits       RSI_9      RSI_14      RSI_25     ewma_7  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data[['Open','High','Low','Close','Volume', 'Dividends','Stock Splits', 'RSI_9','RSI_14','RSI_25','ewma_7','ewma_50','ewma_200']] = scaler.fit_transform(data[['Open','High','Low','Close','Volume', 'Dividends','Stock Splits', 'RSI_9','RSI_14','RSI_25','ewma_7','ewma_50','ewma_200']])

# %%
from pycaret.regression import *

model1 = setup(data = data, target = data['Close_target'],train_size=0.7,preprocess=False, transformation=False,
               remove_multicollinearity=True, multicollinearity_threshold=0.9, feature_selection=True)

best = compare_models()
# Out:
# <style type="text/css">
# </style>
# <table id="T_10915">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10915_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_10915_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10915_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10915_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_10915_row0_col1" class="data row0 col1" >6631</td>
#     </tr>
#     <tr>
#       <th id="T_10915_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10915_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_10915_row1_col1" class="data row1 col1" >Close_target_y</td>
#     </tr>
#     <tr>
#       <th id="T_10915_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10915_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

X = data.drop(['Close_target'], axis=1)
y = data['Close_target']

X_train,X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

model2 = LinearRegression()

model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

results_model2 = {'Model': ['Linear Regression'],'RMSE': [rmse],'R2': [r2] }

results_df = pd.DataFrame(results_model2)
results_df
# Out:
#                Model        RMSE        R2
# 0  Linear Regression  459.968523  0.981059

# %%
X = data.drop(['Close_target','RSI_9','RSI_14','RSI_25','ewma_7','ewma_50','ewma_200'], axis=1)
y = data['Close_target']

X_train,X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

model2 = LinearRegression()

model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

results_model2 = {'Model': ['Linear Regression'],'RMSE': [rmse],'R2': [r2] }

results_df = pd.DataFrame(results_model2)
results_df
# Out:
#                Model        RMSE       R2
# 0  Linear Regression  355.595644  0.98868
